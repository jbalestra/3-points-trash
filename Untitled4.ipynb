# %% [markdown]
# <a href="https://colab.research.google.com/github/jbalestra/3-points-trash/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #Importando a biblioteca pandas, e chamando ela de pd
import matplotlib.pyplot as plt


df = pd.read_csv('/content/Mall_Customers.csv') #Lendo o aquivo com os dados

count_male = 0;
count_female = 0;

for i in df['Gender']:
  if (i == 'Male'):
    count_male += 1
  else:
    count_female += 1

print('A porcentagem de sexos de pessoas que frequentam shoppings é de: ')
print(df['Gender'].value_counts() / df.shape[0] * 100  )
plt.show()


labels = 'Male', 'Female'
sizes = [count_male, count_female]
fig, ax = plt.subplots()
ax.pie(sizes, labels = labels , autopct='%1.1f%%')
plt.show()


print('A média da idade das pessoas que frequentam shoppings é de: ',round (df['Age'].mean()),('anos')) # df['Age'].mean(), uma função do pandas para fazer a média da coluna Age

plt.hist(df["Age"])
plt.show()

print('A média de salario anual (k$) das pessoas que frequentam shoppings é de: ',round (df['Annual Income (k$)'].mean()),('k$'))

plt.hist(df['Annual Income (k$)'])
plt.show()
# Out:
# A porcentagem de sexos de pessoas que frequentam shoppings é de:
# Female    56.0
# Male      44.0
# Name: Gender, dtype: float64
# A média da idade das pessoas que frequentam shoppings é de:  39 anos
# A média de salario anual (k$) das pessoas que frequentam shoppings é de:  61 k$
